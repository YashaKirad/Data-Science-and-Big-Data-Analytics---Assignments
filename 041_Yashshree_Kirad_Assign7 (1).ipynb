# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\yasha\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\yasha\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\yasha\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: joblib in c:\users\yasha\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: click in c:\users\yasha\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: tqdm in c:\users\yasha\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: colorama in c:\users\yasha\appdata\roaming\python\python39\site-packages (from click->nltk>=3.1->textblob) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import libraries
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
import textblob
from textblob import TextBlob
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter
import string
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\yasha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\yasha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yasha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("spam.csv", encoding="latin-1")
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
# Remove unnecessary columns and rename remaining columns
df = df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)
df = df.rename(columns={"v1":"label", "v2":"text"})
df.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.describe()
# Out:
#        label                    text
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30

# %%
df.groupby("label").describe()
# Out:
#        text
#       count unique                                                top freq
# label
# ham    4825   4516                             Sorry, I'll call later   30
# spam    747    653  Please call our customer service representativ...    4

# %%
# labeled spam(1) and ham(0) 
df['spam'] = df['label'].map( {'spam': 1, 'ham': 0} ).astype(int)
df.head()
# Out:
#   label                                               text  spam
# 0   ham  Go until jurong point, crazy.. Available only ...     0
# 1   ham                      Ok lar... Joking wif u oni...     0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3   ham  U dun say so early hor... U c already then say...     0
# 4   ham  Nah I don't think he goes to usf, he lives aro...     0

# %%
# calculate length
df['length'] = df['text'].apply(len)
df.head()
# Out:
#   label                                               text  spam  length
# 0   ham  Go until jurong point, crazy.. Available only ...     0     111
# 1   ham                      Ok lar... Joking wif u oni...     0      29
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     1     155
# 3   ham  U dun say so early hor... U c already then say...     0      49
# 4   ham  Nah I don't think he goes to usf, he lives aro...     0      61

# %%
# Remove punctuation and convert text to lowercase
import string
df["text"] = df["text"].apply(lambda x: x.translate(str.maketrans("", "", string.punctuation)))
df["text"] = df["text"].apply(lambda x: x.lower())
df.head()
# Out:
#   label                                               text  spam  length
# 0   ham  go until jurong point crazy available only in ...     0     111
# 1   ham                            ok lar joking wif u oni     0      29
# 2  spam  free entry in 2 a wkly comp to win fa cup fina...     1     155
# 3   ham        u dun say so early hor u c already then say     0      49
# 4   ham  nah i dont think he goes to usf he lives aroun...     0      61

# %%
# Tokenize text
df["tokens"] = df["text"].apply(nltk.word_tokenize)
df.head()
# Out:
#   label                                               text  spam  length  \
# 0   ham  go until jurong point crazy available only in ...     0     111
# 1   ham                            ok lar joking wif u oni     0      29
# 2  spam  free entry in 2 a wkly comp to win fa cup fina...     1     155
# 3   ham        u dun say so early hor u c already then say     0      49
# 4   ham  nah i dont think he goes to usf he lives aroun...     0      61
#
#                                               tokens
# 0  [go, until, jurong, point, crazy, available, o...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3  [u, dun, say, so, early, hor, u, c, already, t...
# 4  [nah, i, dont, think, he, goes, to, usf, he, l...

# %%
# Remove stop words
stop_words = set(stopwords.words("english"))
df["no_stopwords"] = df["tokens"].apply(lambda x: [word for word in x if word not in stop_words])
df.head()
# Out:
#   label                                               text  spam  length  \
# 0   ham  go until jurong point crazy available only in ...     0     111
# 1   ham                            ok lar joking wif u oni     0      29
# 2  spam  free entry in 2 a wkly comp to win fa cup fina...     1     155
# 3   ham        u dun say so early hor u c already then say     0      49
# 4   ham  nah i dont think he goes to usf he lives aroun...     0      61
#
#                                               tokens  \
# 0  [go, until, jurong, point, crazy, available, o...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3  [u, dun, say, so, early, hor, u, c, already, t...
# 4  [nah, i, dont, think, he, goes, to, usf, he, l...
#
#                                         no_stopwords
# 0  [go, jurong, point, crazy, available, bugis, n...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3      [u, dun, say, early, hor, u, c, already, say]
# 4  [nah, dont, think, goes, usf, lives, around, t...

# %%
# Stem words
porter_stemmer = PorterStemmer()
df["stemmed"] = df["no_stopwords"].apply(lambda x: [porter_stemmer.stem(word) for word in x])
df.head()
# Out:
#   label                                               text  spam  length  \
# 0   ham  go until jurong point crazy available only in ...     0     111
# 1   ham                            ok lar joking wif u oni     0      29
# 2  spam  free entry in 2 a wkly comp to win fa cup fina...     1     155
# 3   ham        u dun say so early hor u c already then say     0      49
# 4   ham  nah i dont think he goes to usf he lives aroun...     0      61
#
#                                               tokens  \
# 0  [go, until, jurong, point, crazy, available, o...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3  [u, dun, say, so, early, hor, u, c, already, t...
# 4  [nah, i, dont, think, he, goes, to, usf, he, l...
#
#                                         no_stopwords  \
# 0  [go, jurong, point, crazy, available, bugis, n...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3      [u, dun, say, early, hor, u, c, already, say]
# 4  [nah, dont, think, goes, usf, lives, around, t...
#
#                                              stemmed
# 0  [go, jurong, point, crazi, avail, bugi, n, gre...
# 1                       [ok, lar, joke, wif, u, oni]
# 2  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3      [u, dun, say, earli, hor, u, c, alreadi, say]
# 4  [nah, dont, think, goe, usf, live, around, tho...

# %%
# Lemmatize words
import nltk
nltk.download('omw-1.4')
wordnet_lemmatizer = WordNetLemmatizer()
df["lemmatized"] = df["no_stopwords"].apply(lambda x: [wordnet_lemmatizer.lemmatize(word) for word in x])
df.head()
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\yasha\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#   label                                               text  spam  length  \
# 0   ham  go until jurong point crazy available only in ...     0     111
# 1   ham                            ok lar joking wif u oni     0      29
# 2  spam  free entry in 2 a wkly comp to win fa cup fina...     1     155
# 3   ham        u dun say so early hor u c already then say     0      49
# 4   ham  nah i dont think he goes to usf he lives aroun...     0      61
#
#                                               tokens  \
# 0  [go, until, jurong, point, crazy, available, o...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3  [u, dun, say, so, early, hor, u, c, already, t...
# 4  [nah, i, dont, think, he, goes, to, usf, he, l...
#
#                                         no_stopwords  \
# 0  [go, jurong, point, crazy, available, bugis, n...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3      [u, dun, say, early, hor, u, c, already, say]
# 4  [nah, dont, think, goes, usf, lives, around, t...
#
#                                              stemmed  \
# 0  [go, jurong, point, crazi, avail, bugi, n, gre...
# 1                       [ok, lar, joke, wif, u, oni]
# 2  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3      [u, dun, say, earli, hor, u, c, alreadi, say]
# 4  [nah, dont, think, goe, usf, live, around, tho...
#
#                                           lemmatized
# 0  [go, jurong, point, crazy, available, bugis, n...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3      [u, dun, say, early, hor, u, c, already, say]
# 4  [nah, dont, think, go, usf, life, around, though]

# %%
# perform POS tagging on words in 'new' column
df['PoS'] = df['lemmatized'].apply(lambda x: TextBlob(" ".join(x)).tags)

df.head()
# Out:
#   label                                               text  spam  length  \
# 0   ham  go until jurong point crazy available only in ...     0     111
# 1   ham                            ok lar joking wif u oni     0      29
# 2  spam  free entry in 2 a wkly comp to win fa cup fina...     1     155
# 3   ham        u dun say so early hor u c already then say     0      49
# 4   ham  nah i dont think he goes to usf he lives aroun...     0      61
#
#                                               tokens  \
# 0  [go, until, jurong, point, crazy, available, o...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3  [u, dun, say, so, early, hor, u, c, already, t...
# 4  [nah, i, dont, think, he, goes, to, usf, he, l...
#
#                                         no_stopwords  \
# 0  [go, jurong, point, crazy, available, bugis, n...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3      [u, dun, say, early, hor, u, c, already, say]
# 4  [nah, dont, think, goes, usf, lives, around, t...
#
#                                              stemmed  \
# 0  [go, jurong, point, crazi, avail, bugi, n, gre...
# 1                       [ok, lar, joke, wif, u, oni]
# 2  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3      [u, dun, say, earli, hor, u, c, alreadi, say]
# 4  [nah, dont, think, goe, usf, live, around, tho...
#
#                                           lemmatized  \
# 0  [go, jurong, point, crazy, available, bugis, n...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3      [u, dun, say, early, hor, u, c, already, say]
# 4  [nah, dont, think, go, usf, life, around, though]
#
#                                                  PoS
# 0  [(go, VB), (jurong, JJ), (point, NN), (crazy, ...
# 1  [(ok, JJ), (lar, JJ), (joking, NN), (wif, NN),...
# 2  [(free, JJ), (entry, NN), (2, CD), (wkly, JJ),...
# 3  [(u, JJ), (dun, NNS), (say, VBP), (early, JJ),...
# 4  [(nah, JJ), (dont, NN), (think, VBP), (go, VB)...

# %%
# calculating TF-IDF
import numpy as np
# Calculate term frequency-inverse document frequency (TF-IDF)
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(df["text"])
tfidf_matrix
np.shape(tfidf_matrix)
# Out:
# (5572, 9489)

# %%
print(tfidf_matrix)
# Out:
#   (0, 8970)	0.18533165691076994
#   (0, 1175)	0.3250449070795673
#   (0, 3854)	0.15270009724843112
#   (0, 8294)	0.16130201278165904
#   (0, 2220)	0.2745992510031893
#   (0, 1882)	0.31029049851508855
#   (0, 4862)	0.2745992510031893
#   (0, 9217)	0.22415359492681128
#   (0, 3894)	0.18091547501948232
#   (0, 1884)	0.2745992510031893
#   (0, 4412)	0.10738812897109133
#   (0, 6051)	0.15692628542364076
#   (0, 1414)	0.24717036276041154
#   (0, 2504)	0.2517249054607048
#   (0, 6455)	0.2542354766383449
#   (0, 4704)	0.3250449070795673
#   (0, 8713)	0.22901264860015585
#   (0, 3797)	0.1477812426595277
#   (1, 6045)	0.5462557824449175
#   (1, 9110)	0.4313385731102942
#   (1, 4672)	0.5233273701797004
#   (1, 4901)	0.4080505634471753
#   (1, 6011)	0.2741803362458879
#   (2, 71)	0.2285734546867353
#   (2, 1264)	0.1651212712540757
#   :	:
#   (5570, 3709)	0.26641542926787287
#   (5570, 3114)	0.23615420421305283
#   (5570, 7651)	0.19927105704143783
#   (5570, 1912)	0.13359021497216086
#   (5570, 8754)	0.20450406045006103
#   (5570, 2798)	0.1812088983214566
#   (5570, 5790)	0.20327528479429632
#   (5570, 9019)	0.18396606027585644
#   (5570, 1554)	0.13866890242167798
#   (5570, 8273)	0.09927247201548697
#   (5570, 4553)	0.12492981807611152
#   (5570, 3536)	0.11780296902303605
#   (5570, 7640)	0.178954755080822
#   (5570, 5013)	0.15483862680748686
#   (5570, 4354)	0.2259207383381554
#   (5570, 1191)	0.1089180170707174
#   (5570, 4049)	0.17291750472380726
#   (5570, 8417)	0.08108192048762472
#   (5570, 3587)	0.15516482235361787
#   (5570, 4412)	0.10877813130072099
#   (5571, 7070)	0.5676139326657255
#   (5571, 8562)	0.4413669395336451
#   (5571, 5702)	0.40242233053239684
#   (5571, 4572)	0.5459866786926955
#   (5571, 8417)	0.15154030061157495
