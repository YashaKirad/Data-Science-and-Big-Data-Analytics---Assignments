# %% [markdown]
# ## DSBDA Assignment 3
#
#
# Name - Yashshree Kirad
#
# Roll No - 41
#
# Batch - T2
#
# Branch - TE Comp

# %% [markdown]
# ## Part 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("customer.csv" )

# %%
df
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
a=df.groupby("Employees_status")["Age"]

# %%
a.describe()
# Out:
#                   count       mean        std   min   25%   50%   75%   max
# Employees_status
# Employees         930.0  47.448387  18.229019  15.0  32.0  48.0  63.0  78.0
# Unemployment      252.0  44.492063  17.502303  15.0  31.0  43.0  60.0  78.0
# self-employed     481.0  45.328482  18.372993  15.0  30.0  44.0  61.0  78.0
# workers           781.0  47.322663  18.194628  15.0  32.0  47.0  63.0  78.0

# %% [markdown]
# ## Part 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import pearsonr
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("virus.csv" )

# %%
df
# Out:
#     ANTI_A  ANTI_B    V1
# 0     2.77    98.1   6.0
# 1     9.79    16.8   6.7
# 2     9.29    13.6   7.5
# 3     3.41     1.6   7.6
# 4     9.83    55.3   8.4
# 5     5.76    94.4   9.3
# 6     2.73    67.2   9.4
# 7     0.17    41.9   9.6
# 8     7.50    22.7  10.6
# 9     0.21    39.6  11.2
# 10    0.66    61.6  11.3
# 11    2.84    78.9  11.5
# 12    7.90    15.5  11.5
# 13    2.00    93.3  11.9
# 14    5.07    87.9  13.0
# 15    2.14    85.0  13.8
# 16    9.94    16.4  14.1
# 17    7.21    20.6  14.9
# 18    4.41     4.8  15.2
# 19    8.70    48.3  15.8
# 20    3.05    86.3  16.5
# 21    9.34    52.6  17.7
# 22    7.36    13.0  21.4
# 23    7.79    61.4  55.5
# 24    4.24    53.3  60.0
# 25    0.63    11.3  61.4
# 26    1.43    26.2  62.1
# 27    1.44    32.9  64.9
# 28    7.34    83.4  64.9
# 29    1.74    12.7  69.0
# 30    6.12    35.4  70.1
# 31    7.59    76.7  73.4
# 32    7.31    58.4  74.9
# 33    7.17    86.9  76.8
# 34    2.99    20.6  77.0
# 35    2.84    33.6  77.9
# ...

# %%
min_value_V = df['V1'].min()
max_value_V = df['V1'].max()
print(min_value_V)
print(max_value_V)
# Out:
# 6.0
# 90.7

# %%
#equal width binning

# %%
labe=["A","B","C","D","E"]

# %%
df['width']=pd.cut(df["V1"],5,labels=labe)

# %%
df
# Out:
#     ANTI_A  ANTI_B    V1 width
# 0     2.77    98.1   6.0     A
# 1     9.79    16.8   6.7     A
# 2     9.29    13.6   7.5     A
# 3     3.41     1.6   7.6     A
# 4     9.83    55.3   8.4     A
# 5     5.76    94.4   9.3     A
# 6     2.73    67.2   9.4     A
# 7     0.17    41.9   9.6     A
# 8     7.50    22.7  10.6     A
# 9     0.21    39.6  11.2     A
# 10    0.66    61.6  11.3     A
# 11    2.84    78.9  11.5     A
# 12    7.90    15.5  11.5     A
# 13    2.00    93.3  11.9     A
# 14    5.07    87.9  13.0     A
# 15    2.14    85.0  13.8     A
# 16    9.94    16.4  14.1     A
# 17    7.21    20.6  14.9     A
# 18    4.41     4.8  15.2     A
# 19    8.70    48.3  15.8     A
# 20    3.05    86.3  16.5     A
# 21    9.34    52.6  17.7     A
# 22    7.36    13.0  21.4     A
# 23    7.79    61.4  55.5     C
# 24    4.24    53.3  60.0     D
# 25    0.63    11.3  61.4     D
# 26    1.43    26.2  62.1     D
# 27    1.44    32.9  64.9     D
# 28    7.34    83.4  64.9     D
# ...

# %%
#equal freq
la=["1","2","3","4","5"]
df['freq']=pd.qcut(df["V1"],q=5,labels=la)

# %%
df
# Out:
#     ANTI_A  ANTI_B    V1 width freq
# 0     2.77    98.1   6.0     A    1
# 1     9.79    16.8   6.7     A    1
# 2     9.29    13.6   7.5     A    1
# 3     3.41     1.6   7.6     A    1
# 4     9.83    55.3   8.4     A    1
# 5     5.76    94.4   9.3     A    1
# 6     2.73    67.2   9.4     A    1
# 7     0.17    41.9   9.6     A    1
# 8     7.50    22.7  10.6     A    2
# 9     0.21    39.6  11.2     A    2
# 10    0.66    61.6  11.3     A    2
# 11    2.84    78.9  11.5     A    2
# 12    7.90    15.5  11.5     A    2
# 13    2.00    93.3  11.9     A    2
# 14    5.07    87.9  13.0     A    2
# 15    2.14    85.0  13.8     A    2
# 16    9.94    16.4  14.1     A    3
# 17    7.21    20.6  14.9     A    3
# 18    4.41     4.8  15.2     A    3
# 19    8.70    48.3  15.8     A    3
# 20    3.05    86.3  16.5     A    3
# 21    9.34    52.6  17.7     A    3
# 22    7.36    13.0  21.4     A    3
# 23    7.79    61.4  55.5     C    3
# 24    4.24    53.3  60.0     D    4
# ...

# %%
cat=["low","high"]
bins = np.linspace(min_value_V,max_value_V,3)
df['group'] = pd.cut(df['V1'], bins=bins, labels=cat, include_lowest=True)
df
# Out:
#     ANTI_A  ANTI_B    V1 width freq group
# 0     2.77    98.1   6.0     A    1   low
# 1     9.79    16.8   6.7     A    1   low
# 2     9.29    13.6   7.5     A    1   low
# 3     3.41     1.6   7.6     A    1   low
# 4     9.83    55.3   8.4     A    1   low
# 5     5.76    94.4   9.3     A    1   low
# 6     2.73    67.2   9.4     A    1   low
# 7     0.17    41.9   9.6     A    1   low
# 8     7.50    22.7  10.6     A    2   low
# 9     0.21    39.6  11.2     A    2   low
# 10    0.66    61.6  11.3     A    2   low
# 11    2.84    78.9  11.5     A    2   low
# 12    7.90    15.5  11.5     A    2   low
# 13    2.00    93.3  11.9     A    2   low
# 14    5.07    87.9  13.0     A    2   low
# 15    2.14    85.0  13.8     A    2   low
# 16    9.94    16.4  14.1     A    3   low
# 17    7.21    20.6  14.9     A    3   low
# 18    4.41     4.8  15.2     A    3   low
# 19    8.70    48.3  15.8     A    3   low
# 20    3.05    86.3  16.5     A    3   low
# ...

# %%
grouped=df.groupby(df.group)
g1=grouped.get_group("low")
g2=grouped.get_group("high")

# %%
print(g1)
# Out:
#     ANTI_A  ANTI_B    V1 width freq group
# 0     2.77    98.1   6.0     A    1   low
# 1     9.79    16.8   6.7     A    1   low
# 2     9.29    13.6   7.5     A    1   low
# 3     3.41     1.6   7.6     A    1   low
# 4     9.83    55.3   8.4     A    1   low
# 5     5.76    94.4   9.3     A    1   low
# 6     2.73    67.2   9.4     A    1   low
# 7     0.17    41.9   9.6     A    1   low
# 8     7.50    22.7  10.6     A    2   low
# 9     0.21    39.6  11.2     A    2   low
# 10    0.66    61.6  11.3     A    2   low
# 11    2.84    78.9  11.5     A    2   low
# 12    7.90    15.5  11.5     A    2   low
# 13    2.00    93.3  11.9     A    2   low
# 14    5.07    87.9  13.0     A    2   low
# 15    2.14    85.0  13.8     A    2   low
# 16    9.94    16.4  14.1     A    3   low
# 17    7.21    20.6  14.9     A    3   low
# 18    4.41     4.8  15.2     A    3   low
# 19    8.70    48.3  15.8     A    3   low
# 20    3.05    86.3  16.5     A    3   low
# ...

# %%
print(g2)
# Out:
#     ANTI_A  ANTI_B    V1 width freq group
# 23    7.79    61.4  55.5     C    3  high
# 24    4.24    53.3  60.0     D    4  high
# 25    0.63    11.3  61.4     D    4  high
# 26    1.43    26.2  62.1     D    4  high
# 27    1.44    32.9  64.9     D    4  high
# 28    7.34    83.4  64.9     D    4  high
# 29    1.74    12.7  69.0     D    4  high
# 30    6.12    35.4  70.1     D    4  high
# 31    7.59    76.7  73.4     D    4  high
# 32    7.31    58.4  74.9     E    5  high
# 33    7.17    86.9  76.8     E    5  high
# 34    2.99    20.6  77.0     E    5  high
# 35    2.84    33.6  77.9     E    5  high
# 36    0.67     9.2  80.1     E    5  high
# 37    8.62    78.9  81.2     E    5  high
# 38    7.44    98.8  83.8     E    5  high
# 39    7.21    88.0  90.7     E    5  high

# %%
mean_g1=g1["V1"].mean()
print(mean_g1)
# Out:
# 11.952173913043477

# %%
mean_g2=g2["V1"].mean()
print(mean_g2)
# Out:
# 71.98235294117646

# %%
median_g1=g1["V1"].median()
print(median_g1)
# Out:
# 11.5

# %%
median_g2=g2["V1"].median()
print(median_g2)
# Out:
# 73.4

# %%
std_g1=g1["V1"].std()
print(std_g1)
# Out:
# 3.8308401126096934

# %%
std_g2=g2["V1"].std()
print(std_g2)
# Out:
# 9.593111805751409

# %%
q1_g1=g1["V1"].quantile(q=0.25)
print(q1_g1)
# Out:
# 9.350000000000001

# %%
q1_g2=g2["V1"].quantile(q=0.25)
print(q1_g2)
# Out:
# 64.9

# %%
q3_g1=g1["V1"].quantile(q=0.75)
print(q3_g1)
# Out:
# 14.5

# %%
q3_g2=g2["V1"].quantile(q=0.75)
print(q3_g2)
# Out:
# 77.9

# %%
plt.boxplot(g1['V1'])
plt.title('Box plot of v1 in group 1')
plt.ylabel('V1')
plt.show()

# %%
plt.boxplot(g2['V1'])
plt.title('Box plot of v1 in group 2')
plt.ylabel('V1')
plt.show()

# %%
g3=g1.copy()
g4=g2.copy()
print(g3)
print('\n')
print(g4)
# Out:
#     ANTI_A  ANTI_B    V1 width freq group
# 0     2.77    98.1   6.0     A    1   low
# 1     9.79    16.8   6.7     A    1   low
# 2     9.29    13.6   7.5     A    1   low
# 3     3.41     1.6   7.6     A    1   low
# 4     9.83    55.3   8.4     A    1   low
# 5     5.76    94.4   9.3     A    1   low
# 6     2.73    67.2   9.4     A    1   low
# 7     0.17    41.9   9.6     A    1   low
# 8     7.50    22.7  10.6     A    2   low
# 9     0.21    39.6  11.2     A    2   low
# 10    0.66    61.6  11.3     A    2   low
# 11    2.84    78.9  11.5     A    2   low
# 12    7.90    15.5  11.5     A    2   low
# 13    2.00    93.3  11.9     A    2   low
# 14    5.07    87.9  13.0     A    2   low
# 15    2.14    85.0  13.8     A    2   low
# 16    9.94    16.4  14.1     A    3   low
# 17    7.21    20.6  14.9     A    3   low
# 18    4.41     4.8  15.2     A    3   low
# 19    8.70    48.3  15.8     A    3   low
# 20    3.05    86.3  16.5     A    3   low
# ...

# %%
g3['ANTI_A']= (g3['ANTI_A']-g3['ANTI_A'].min())/(g3['ANTI_A'].max()-g3['ANTI_A'].min())
g3['ANTI_B']= (g3['ANTI_B']-g3['ANTI_B'].min())/(g3['ANTI_B'].max()-g3['ANTI_B'].min())

print(g3)
# Out:
#       ANTI_A    ANTI_B    V1 width freq group
# 0   0.266121  1.000000   6.0     A    1   low
# 1   0.984647  0.157513   6.7     A    1   low
# 2   0.933470  0.124352   7.5     A    1   low
# 3   0.331627  0.000000   7.6     A    1   low
# 4   0.988741  0.556477   8.4     A    1   low
# 5   0.572160  0.961658   9.3     A    1   low
# 6   0.262027  0.679793   9.4     A    1   low
# 7   0.000000  0.417617   9.6     A    1   low
# 8   0.750256  0.218653  10.6     A    2   low
# 9   0.004094  0.393782  11.2     A    2   low
# 10  0.050154  0.621762  11.3     A    2   low
# 11  0.273286  0.801036  11.5     A    2   low
# 12  0.791198  0.144041  11.5     A    2   low
# 13  0.187308  0.950259  11.9     A    2   low
# 14  0.501535  0.894301  13.0     A    2   low
# 15  0.201638  0.864249  13.8     A    2   low
# 16  1.000000  0.153368  14.1     A    3   low
# 17  0.720573  0.196891  14.9     A    3   low
# 18  0.433982  0.033161  15.2     A    3   low
# ...

# %%
g4['ANTI_A']= (g4['ANTI_A']-g4['ANTI_A'].min())/(g4['ANTI_A'].max()-g4['ANTI_A'].min())

g4['ANTI_B']= (g4['ANTI_B']-g4['ANTI_B'].min())/(g4['ANTI_B'].max()-g4['ANTI_B'].min())

print(g4)
# Out:
#       ANTI_A    ANTI_B    V1 width freq group
# 23  0.896120  0.582589  55.5     C    3  high
# 24  0.451815  0.492187  60.0     D    4  high
# 25  0.000000  0.023438  61.4     D    4  high
# 26  0.100125  0.189732  62.1     D    4  high
# 27  0.101377  0.264509  64.9     D    4  high
# 28  0.839800  0.828125  64.9     D    4  high
# 29  0.138924  0.039062  69.0     D    4  high
# 30  0.687109  0.292411  70.1     D    4  high
# 31  0.871089  0.753348  73.4     D    4  high
# 32  0.836045  0.549107  74.9     E    5  high
# 33  0.818523  0.867188  76.8     E    5  high
# 34  0.295369  0.127232  77.0     E    5  high
# 35  0.276596  0.272321  77.9     E    5  high
# 36  0.005006  0.000000  80.1     E    5  high
# 37  1.000000  0.777902  81.2     E    5  high
# 38  0.852315  1.000000  83.8     E    5  high
# 39  0.823529  0.879464  90.7     E    5  high

# %%
df
# Out:
#     ANTI_A  ANTI_B    V1 width freq group
# 0     2.77    98.1   6.0     A    1   low
# 1     9.79    16.8   6.7     A    1   low
# 2     9.29    13.6   7.5     A    1   low
# 3     3.41     1.6   7.6     A    1   low
# 4     9.83    55.3   8.4     A    1   low
# 5     5.76    94.4   9.3     A    1   low
# 6     2.73    67.2   9.4     A    1   low
# 7     0.17    41.9   9.6     A    1   low
# 8     7.50    22.7  10.6     A    2   low
# 9     0.21    39.6  11.2     A    2   low
# 10    0.66    61.6  11.3     A    2   low
# 11    2.84    78.9  11.5     A    2   low
# 12    7.90    15.5  11.5     A    2   low
# 13    2.00    93.3  11.9     A    2   low
# 14    5.07    87.9  13.0     A    2   low
# 15    2.14    85.0  13.8     A    2   low
# 16    9.94    16.4  14.1     A    3   low
# 17    7.21    20.6  14.9     A    3   low
# 18    4.41     4.8  15.2     A    3   low
# 19    8.70    48.3  15.8     A    3   low
# 20    3.05    86.3  16.5     A    3   low
# ...

# %%
g3.plot(x='ANTI_A', y='ANTI_B',kind='scatter')
plt.xlabel('Normalized ANTI_A')
plt.ylabel('Normalized ANTI_B')
plt.show()

# %%
g4.plot(x='ANTI_A', y='ANTI_B',kind='scatter')
plt.xlabel('Normalized ANTI_A')
plt.ylabel('Normalized ANTI_B')
plt.show()

# %%
print(g3['ANTI_A'].corr(g3['ANTI_B']))
# Out:
# -0.44962747254599306

# %%
print(g4['ANTI_A'].corr(g4['ANTI_B']))
# Out:
# 0.8938242533758364

# %% [markdown]
# ## Conclusion
#
# Part 1 -
# Thus we have successfully implemented the problem statement and able to perform statisical analysis on the datast
#
# Part 2-
# Group 1 has negative corelation,hence when one varialble eg Anti_A changes the other variable
# Anti_B changes in opposite direction.
# Group 2 has positive corelation hence when one variable i.e Anti_A changes
# the other variable Anti_B changes in the same direction.
